# %%
import pandas as pd

# %%
iris_df=pd.read_csv("Iris_data_set.csv")
data_frame=iris_df.copy()
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data_frame.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data_frame.petal_width>0.2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: petal_width, Length: 150, dtype: bool

# %%
data_frame[data_frame.petal_width>0.2]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# 16            5.4          3.9           1.3          0.4     setosa
# 17            5.1          3.5           1.4          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [116 rows x 5 columns]

# %%
data_frame[data_frame.petal_width>0.2].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    116.000000   116.000000    116.000000   116.000000
# mean       6.105172     2.963793      4.438793     1.496552
# std        0.740369     0.419606      1.402406     0.599410
# min        4.500000     2.000000      1.300000     0.300000
# 25%        5.600000     2.700000      4.000000     1.200000
# 50%        6.100000     3.000000      4.700000     1.500000
# 75%        6.600000     3.200000      5.400000     1.925000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data_frame[data_frame.species=='setosa'].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        5.00600     3.418000      1.464000      0.24400
# std         0.35249     0.381024      0.173511      0.10721
# min         4.30000     2.300000      1.000000      0.10000
# 25%         4.80000     3.125000      1.400000      0.20000
# 50%         5.00000     3.400000      1.500000      0.20000
# 75%         5.20000     3.675000      1.575000      0.30000
# max         5.80000     4.400000      1.900000      0.60000

# %%
print(data_frame.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#to print 1st row
print(data_frame.iloc[0])
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
#to print row of index 1
print(data_frame.loc[1])
# Out:
# sepal_length       4.9
# sepal_width        3.0
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 1, dtype: object

# %%
#deleting 1st row
data_frame.drop(0,inplace=True)
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
#adding 1st row
data_frame.loc[0]=[4.5,3.1,1.5,0.3,"setosa"]
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
data_frame.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
# 0             4.5          3.1           1.5          0.3     setosa

# %%
data_frame.reset_index(drop=True,inplace=True)
print(data_frame)
# Out:
#      level_0  index  sepal_length  sepal_width  petal_length  petal_width  \
# 0          0      1           4.9          3.0           1.4          0.2
# 1          1      2           4.7          3.2           1.3          0.2
# 2          2      3           4.6          3.1           1.5          0.2
# 3          3      4           5.0          3.6           1.4          0.2
# 4          4      5           5.4          3.9           1.7          0.4
# ..       ...    ...           ...          ...           ...          ...
# 145      145    146           6.3          2.5           5.0          1.9
# 146      146    147           6.5          3.0           5.2          2.0
# 147      147    148           6.2          3.4           5.4          2.3
# 148      148    149           5.9          3.0           5.1          1.8
# 149      149      0           4.5          3.1           1.5          0.3
#
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# ...

# %%
#data_frame.drop(columns=["level_0"],inplace=True)
#data_frame.drop(columns=["index"],inplace=True)
#alredy deleted level_0 and index columns using above code
print(data_frame)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             4.9          3.0           1.4          0.2     setosa
# 1             4.7          3.2           1.3          0.2     setosa
# 2             4.6          3.1           1.5          0.2     setosa
# 3             5.0          3.6           1.4          0.2     setosa
# 4             5.4          3.9           1.7          0.4     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.3          2.5           5.0          1.9  virginica
# 146           6.5          3.0           5.2          2.0  virginica
# 147           6.2          3.4           5.4          2.3  virginica
# 148           5.9          3.0           5.1          1.8  virginica
# 149           4.5          3.1           1.5          0.3     setosa
#
# [150 rows x 5 columns]

# %%
data_frame.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.839333     3.051333      3.759333     1.199333
# std        0.833115     0.432060      1.763542     0.762326
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#delete column
del data_frame["sepal_width"]
data_frame.describe()
# Out:
#        sepal_length  petal_length  petal_width
# count    150.000000    150.000000   150.000000
# mean       5.839333      3.759333     1.199333
# std        0.833115      1.763542     0.762326
# min        4.300000      1.000000     0.100000
# 25%        5.100000      1.600000     0.300000
# 50%        5.800000      4.350000     1.300000
# 75%        6.400000      5.100000     1.800000
# max        7.900000      6.900000     2.500000

# %%
data_frame["color"]='white'
data_frame.head()
# Out:
#    sepal_length  petal_length  petal_width species  color
# 0           4.9           1.4          0.2  setosa  white
# 1           4.7           1.3          0.2  setosa  white
# 2           4.6           1.5          0.2  setosa  white
# 3           5.0           1.4          0.2  setosa  white
# 4           5.4           1.7          0.4  setosa  white
